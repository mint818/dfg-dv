# %%
import pandas as pd

# %%
df = pd.read_csv('zip code vs population.csv')

# %%
df
# Out:
#       zip code population
# 0        45011     72,971
# 1        43123     66,351
# 2        44256     64,568
# 3        43081     64,387
# 4        43026     63,295
# ...        ...        ...
# 1212     43914         29
# 1213     43520         23
# 1214     43047         22
# 1215     43736         22
# 1216     45267          4
#
# [1217 rows x 2 columns]
